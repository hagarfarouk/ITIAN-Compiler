# %%
# The calculator
#----------------------------------------------------------------
#Operation functions

from operator import*

def Addition(n1,n2):
    return (n1+n2)
def Multiplication(n1,n2):
    return (n1*n2)
def Subtraction(n1,n2):
    return (n1-n2)
def Divition(n1,n2):
    return (n1/n2)

#----------------------------------------------------------------

    
    
    
    
print("welcome to the ITIan Calculator")
print("The Calculator has 2 modes")
Num_1=0
Num_2=0
check1=0
conv=0
mode = 0
while mode != 9:
    print("Press 1 for Scientific and 2 for Programming and 9 to close the program")
    mode= int(input("For starters which mode would you like to use : "))
    
    #inputing the numbers

    
    if mode == 1:           #Scientific mode
        print("You have selected the Scientific ")
        check1 = input("type in the operation that you wish to do (+,*,-,!,/,%) ")
        if check1 == '+':
            Num_1= int(input("Type in Both numbers starting with the first number"))  
            Num_2= int(input("Type in the value of the second number"))
            Result = Addition(Num_1,Num_2)
        elif check1 == '-':
            Num_1= int(input("Type in Both numbers starting with the first number"))  
            Num_2= int(input("Type in the value of the second number"))
            Result = Sutraction(Num_1,Num_2)
        elif check1 == '*':
            Num_1= int(input("Type in Both numbers starting with the first number"))  
            Num_2= int(input("Type in the value of the second number"))
            Result = Multiplication(Num_1,Num_2)
        elif check1 == '/':
            Num_1= int(input("Type in Both numbers starting with the first number"))  
            Num_2= int(input("Type in the value of the second number"))
            Result = Divition(Num_1,Num_2)
        elif check1 == '%':
            Num_1= int(input("Type in Both numbers starting with the first number"))  
            Num_2= int(input("Type in the value of the second number"))
            Result = Num_1%Num_2
        elif check1 == '!':
            Result = 1
            Num_1= int(input("Enter the number factorial : "))  
            for i in range(1,Num_1+1):
                Result = Result * i
        
    elif mode ==2:          #programming mode
        print("You have chosen the Programming mode")
        
        print("If you want to change the number from Decimal to Hex/Oct/Binary enter 1")
        check1=int(input("If you want to do an operation press 2 to do an operation "))
        if check1 == 1:
            print("To change the number to Hex : Press 1")
            print("To change the number to Octan : Press 2")
            conv = int(input("To change the number to Binary : Press 3"))
            Num_1 = int(input("Enter the First number to be converted"))
            Num_2 = int(input("Enter the Second number to be converted : "))
            if conv == 1:
                Num_1 = hex(Num_1)
                Num_2=hex(Num_2)
                print("is The first number converted to Hexadecimal : ", Num_1[2:])
                print("is The Second number converted to Hexadecimal : ", Num_2[2:])
            elif conv == 2:
                Num_1 = oct(Num_1)
                Num_2=oct(Num_2)
                print("is The first number converted to Octa :", Num_1[2:])
                print("is The Second number converted to Octa :", Num_2[2:])
            elif conv == 3:
                Num_1=bin(Num_1)
                Num_2=bin(Num_2)
                print("is The first number converted to Binary :", Num_1[2:])
                print("is The Second number converted to Binary :", Num_2[2:])
                
        contin = int(input("Enter number 4 to do an operation on these numbers OR to use them in decimal press 5 : "))
        if contin == 4:
            check1 = 2
        elif contin == 5:
            check1 = 2
            if conv == 3:
                Num_1= int(Num_1,2)
                Num_2= int(Num_2,2)
                conv=0
            elif conv == 1:
                Num_1= int(Num_1,16)
                Num_2= int(Num_2,16)
                conv=0
            elif conv ==2:
                Num_1= int(Num_1,8)
                Num_2= int(Num_2,8)
                conv=0
                
        if check1 == 2:
            if contin != 4 and contin != 5 :
                Num_1= int(input("Type in Both numbers starting with the first number :"))  
                Num_2= int(input("Type in the value of the second number :"))
            check1 = input("type in the operation that you wish to do (+,*,-,/) ")
            if check1 == '+':
                if conv ==3:
                    Result=(bin(add(int(Num_1,2),int(Num_2,2))))
                elif conv ==2:
                    Result=(oct(add(int(Num_1,8),int(Num_2,8))))
                elif conv ==1:
                    Result=(hex(add(int(Num_1,16),int(Num_2,16))))
                else:
                    Result = Addition(Num_1,Num_2)
            elif check1 == '-':
                if conv ==3:
                    Result = bin(int(Num_1, 2) - int(Num_2, 2))
                elif conv ==2:
                    Result=oct(int(Num_1,8) - int(Num_2,8))
                elif conv ==1:
                    Result=hex(int(Num_1,16) - int(Num_2,16))
                else:
                    Result = Subtraction(Num_1,Num_2)
            elif check1 == '*':
                if conv ==3:
                    Result = bin(int(Num_1, 2) * int(Num_2, 2))
                elif conv ==2:
                    Result=oct(int(Num_1,8) * int(Num_2,8))
                elif conv ==1:
                    Result=hex(int(Num_1,16) * int(Num_2,16))
                else:
                    Result = Multiplication(Num_1,Num_2)
            elif check1 == '/':
                if conv ==3:
                    Result = bin(int(Num_1, 2) / int(Num_2, 2))
                elif conv ==2:
                    Result=oct(int(Num_1,8) / int(Num_2,8))
                elif conv ==1:
                    Result=hex(int(Num_1,16) / int(Num_2,16))
                
                else:
                    Result = Divition(Num_1,Num_2)
    print("The result is : ", Result)
    Result=0
#scientific
#programming
# Out:
# welcome to the ITIan Calculator
# The Calculator has 2 modes
# Press 1 for Scientific and 2 for Programming and 9 to close the program
# For starters which mode would you like to use : 2
# You have chosen the Programming mode
# If you want to change the number from Decimal to Hex/Oct/Binary enter 1
# If you want to do an operation press 2 to do an operation 1
# To change the number to Hex : Press 1
# To change the number to Octan : Press 2
# To change the number to Binary : Press 31
# Enter the First number to be converted5
# Enter the Second number to be converted60
# is The first number converted to Hexadecimal  5
# is The Second number converted to Hexadecimal  3c
# Enter number 4 to do an operation on these numbers OR to use them in decimal press 5 5
# type in the operation that you wish to do (+,*,-,/) +
# The result is :  65
# Press 1 for Scientific and 2 for Programming and 9 to close the program
# For starters which mode would you like to use : 2
# ...
